# %% [markdown]
# ## Data Cleaning and Analysis -- Problem Set 9: EDA and Data Visualization
# In this problem set, you will analyze and visualize the disolved oxygen measurements in the Bridgeport Harbor from the `BridgeportDO.csv` dataset.  Your task is to practice exploratory data analysis (EDA) and visualization techniques to uncover patterns, assess distributions, and evaluate data quality. Recall from lecture that the CSV contains the following variables:
#
#     - Harbor Name: the name of the harbor where measurements were collected
#     - Date: the sampling date of the measurement
#     - DissolvedOxygen: the concentration of dissolved oxygen (mg/L)
#     - Salinity: the salinity of the water sample (ppt)
#     - PH: the pH level of the water sample
#
# As always, use sources like Google, Stack Overflow, documentation, and other forums for help. Try to avoid AI in order to develop your own ability to conceptualize solution strategies.

# %% [markdown]
# ## Setup & Data
# Load required packages for data exploration and data visualization. Then, load the dataset used in lecture.

# %%
library(tidyverse)
library(ggplot2)

# Bridgeport Harbor Dissolved Oxygen Data (as used in lecture)
dissox <- read.csv("https://raw.githubusercontent.com/yse-eds-cert/practice-set-9/main/data/BridgeportDO.csv", header = TRUE)

# %% [markdown]
# ## Question 1: Pairwise Exploration (6 points)
#
# ### Part A: Dissolved oxygen and salinity (3 points)
#
# First, we want to explore the relationship between dissolved oxygen and salinity. Saltier water usually holds less oxygen because salt reduces how much oxygen can dissolve in water. Changes in salinity can also reflect tides or freshwater inflows, which affect oxygen levels by changing temperature, density, and nutrients.
#
# 1. Create a scatterplot of dissolved oxygen against salinity to visualize how these two variables relate.
# 2. Describe the overall pattern in the plot. Does the relationship appear roughly linear, curved, or is there little to no clear pattern?
# 3. Interpret the direction of the relationship. As salinity increases, do you generally see dissolved oxygen values rising, falling, or staying the same?

# %%
# ✏️ Your code here

# %% [markdown]
# *✏️ Write your answer here.*

# %% [markdown]
# ### Part B: Dissolved oxygen and pH (3 points)
#
# Next, explore the relationship between dissolved oxygen and pH. Photosynthesis consumes carbon dioxide (CO₂) and releases oxygen (O₂), which raises both pH and dissolved oxygen levels in the water. On the other hand, respiration uses oxygen and produces carbon dioxide, lowering pH and reducing dissolved oxygen. These complementary processes could help explain how pH and dissolved oxygen vary together in aquatic systems.
#
# Provide reflections from your exploration. You can use the same guiding questions from the previous part.

# %%
# ✏️ Your code here

# %% [markdown]
# *✏️ Write your answer here.*

# %% [markdown]
# ## Question 2: Correlation and Visualizations (6 points)
#
# ### Part A (1 point)
#
# Since we have visualized the relationship between these variables, is calculating the sample correlation appropriate for evaluating the relationship between dissolved oxygen and salinity? and between dissolved oxygen and pH?

# %% [markdown]
# *✏️ Write your answer here.*

# %% [markdown]
# ### Part B (3 points)
#
# Now, we can compute sample correlations.
#
# 1. Compute the sample correlation between dissolved oxygen and salinity, and between dissolved oxygen and pH.
# 2. Which relationship is stronger?
# 3. Does the sign of the coefficient match what you expected from the scatterplots?

# %%
# ✏️ Your code here

# %% [markdown]
# *✏️ Write your answer here.*

# %% [markdown]
# ### Part C (2 points)
#
# Recall that in the previous problem set, we used GGally for quick correlational analyses. Now, create a pairs plot (scatterplot matrix) that includes dissolved oxygen, salinity, and pH. This will let you see how each variable relates to the others in a single figure.
#
# 1. Create a new dataframe that contains a subset of the original data frame with only the three variables of interest
# 2. Use `ggpairs()` to create a pairs plot. Hint: you will need to load the GGally package if you have not already

# %%
# ✏️ Your code here

# %% [markdown]
# ## Question 3: Distributions and Density Functions (4 points)
#
# Since the correlation between pH and dissolved oxygen is positive and statistically significant (as indicated by the *** in the `ggpairs()` plot you created), let's also examine how each variable is distributed.
#
# 1. Create a histogram of dissolved oxygen using `ggplot2`.
# 2. Create a historgam of pH using `ggplot2`.
# 3. Plot the density of both variables in one plot. Hint: you can add multiple `geom_()` layers with `ggplot()`.
# 4. Comment on the shape of the two distributions from part 3.

# %%
# ✏️ Your code here

# %% [markdown]
# *✏️ Write your answer here.*

# %% [markdown]
# ## Question 4: Assessing Normality (4 points)
#
# In lecture, we saw that Quantile-Quantile plots (QQ) plots can be used to assess whether data are approximately normally distributed.
#
# 1. Using `ggplot2`, make a QQ plot of dissolved oxygen and add the normal reference line.
#     - Map the variable to `aes(sample = ...)`.
#     - Use `stat_qq()` for points and `stat_qq_line()` for the line.
#     - Add a title/labels
# 2. Repeat for pH using the same approach.
# 3. For each plot, describe where the points deviate from the reference line (e.g., in the tails, in the center, or across the entire range).
# 4. Based on these deviations, discuss whether a normal distribution is a reasonable model for each variable and explain your reasoning.

# %%
# ✏️ Your code here

# %% [markdown]
# *✏️ Write your answer here.*

# %% [markdown]
# ---
#
# ## How to submit
#
# When you've finished the problem set:
#
# 1. In the Colab menu bar, click **File → Save a copy in GitHub**.
# 2. In the dialog:
#    - **Repository**: choose the repository Classroom50 created for you when you accepted this assignment (it will have your GitHub username in the name).
#    - **Branch**: `main`.
#    - **File path**: leave the filename as-is so it overwrites the starter notebook.
#    - **Commit message**: something descriptive, e.g. *"Finished pset"*.
# 3. Click **OK**. Colab will push your completed notebook back to your assignment repository.
#
# You can save to GitHub as often as you like — each save is just another commit. Your most recent commit before the due date is what gets graded.
